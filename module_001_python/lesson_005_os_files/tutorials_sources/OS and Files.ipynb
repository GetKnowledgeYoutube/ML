# %% [markdown]
# # 1 - Модуль для работы с операционной системой

# %%
import os
dir(os)
# Out:
# ['DirEntry',
#  'F_OK',
#  'MutableMapping',
#  'O_APPEND',
#  'O_BINARY',
#  'O_CREAT',
#  'O_EXCL',
#  'O_NOINHERIT',
#  'O_RANDOM',
#  'O_RDONLY',
#  'O_RDWR',
#  'O_SEQUENTIAL',
#  'O_SHORT_LIVED',
#  'O_TEMPORARY',
#  'O_TEXT',
#  'O_TRUNC',
#  'O_WRONLY',
#  'P_DETACH',
#  'P_NOWAIT',
#  'P_NOWAITO',
#  'P_OVERLAY',
#  'P_WAIT',
#  'PathLike',
#  'R_OK',
#  'SEEK_CUR',
#  'SEEK_END',
#  'SEEK_SET',
#  'TMP_MAX',
#  'W_OK',
#  'X_OK',
#  '_Environ',
#  '__all__',
#  '__builtins__',
#  '__cached__',
#  '__doc__',
#  '__file__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__spec__',
#  '_execvpe',
#  '_exists',
#  '_exit',
#  '_fspath',
#  '_get_exports_list',
#  '_putenv',
#  '_unsetenv',
#  '_wrap_close',
#  'abc',
#  'abort',
#  'access',
#  'altsep',
#  'chdir',
#  'chmod',
#  'close',
#  'closerange',
#  'cpu_count',
#  'curdir',
#  'defpath',
#  'device_encoding',
#  'devnull',
#  'dup',
#  'dup2',
#  'environ',
#  'error',
#  'execl',
#  'execle',
#  'execlp',
# ...

# %%
print(os.getcwd())
# Out:
# C:\Workplace\ML\module_001_python\lesson_005_os_files\tutorials_sources

# %%
os.chdir('..\\datasets')
print(os.getcwd())
# Out:
# C:\Workplace\ML\module_001_python\lesson_005_os_files\datasets

# %%
os.mkdir('new dir')
print(os.listdir())
os.rmdir('new dir')
print(os.listdir())
# Out:
# ['heart.csv', 'new dir']
# ['heart.csv']

# %%
import shutil
os.makedirs('folder1\\folder2\\folder3')
print(os.listdir())
shutil.rmtree('folder1')
print(os.listdir())
# Out:
# ['folder1', 'heart.csv']
# ['heart.csv']

# %%
os.rename('heart.csv', 'heart2.csv')
print(os.listdir())
os.rename('heart2.csv', 'heart.csv')
print(os.listdir())
# Out:
# ['heart2.csv']
# ['heart.csv']

# %%
from datetime import datetime 
print(os.stat('heart.csv'))
print(datetime.fromtimestamp(os.stat('heart.csv').st_ctime))
# Out:
# os.stat_result(st_mode=33206, st_ino=2814749767245717, st_dev=853542795, st_nlink=1, st_uid=0, st_gid=0, st_size=11021, st_atime=1555143499, st_mtime=1554641700, st_ctime=1555143499)
# 2019-04-13 13:18:19.744701

# %%
os.makedirs('a\\b\\c')
os.makedirs('d\\e\\f')

for dirpath, dirnames, filenames in os.walk(os.getcwd()):
    print('Current path: ', dirpath)
    print('Directories: ', dirnames)
    print('Files: ', filenames)
    print('---------')
# Out:
# Current path:  C:\Workplace\ML\module_001_python\lesson_005_os_files\datasets
# Directories:  ['a', 'd']
# Files:  ['heart.csv']
# ---------
# Current path:  C:\Workplace\ML\module_001_python\lesson_005_os_files\datasets\a
# Directories:  ['b']
# Files:  []
# ---------
# Current path:  C:\Workplace\ML\module_001_python\lesson_005_os_files\datasets\a\b
# Directories:  ['c']
# Files:  []
# ---------
# Current path:  C:\Workplace\ML\module_001_python\lesson_005_os_files\datasets\a\b\c
# Directories:  []
# Files:  []
# ---------
# Current path:  C:\Workplace\ML\module_001_python\lesson_005_os_files\datasets\d
# Directories:  ['e']
# Files:  []
# ---------
# Current path:  C:\Workplace\ML\module_001_python\lesson_005_os_files\datasets\d\e
# Directories:  ['f']
# Files:  []
# ---------
# Current path:  C:\Workplace\ML\module_001_python\lesson_005_os_files\datasets\d\e\f
# Directories:  []
# Files:  []
# ---------

# %% [markdown]
# ## Исполнение внешней программы через ОС

# %%
import subprocess
MyOut = subprocess.Popen(['ipconfig', '/all'], 
            stdout=subprocess.PIPE, 
            stderr=subprocess.STDOUT)
stdout,stderr = MyOut.communicate()
print(stdout.decode('cp866'))
print(stderr)
# Out:
# Настройка протокола IP для Windows
#
#    Имя компьютера  . . . . . . . . . : DESKTOP-ARTDGM1
#    Основной DNS-суффикс  . . . . . . :
#    Тип узла. . . . . . . . . . . . . : Гибридный
#    IP-маршрутизация включена . . . . : Нет
#    WINS-прокси включен . . . . . . . : Нет
#
# Адаптер Ethernet Ethernet 2:
#
#    Состояние среды. . . . . . . . : Среда передачи недоступна.
#    DNS-суффикс подключения . . . . . :
#    Описание. . . . . . . . . . . . . : TAP-NordVPN Windows Adapter V9
#    Физический адрес. . . . . . . . . : 00-FF-4B-B2-35-D1
#    DHCP включен. . . . . . . . . . . : Да
#    Автонастройка включена. . . . . . : Да
#
# Адаптер Ethernet Ethernet:
#
#    DNS-суффикс подключения . . . . . :
#    Описание. . . . . . . . . . . . . : Killer E2200 Gigabit Ethernet Controller
#    Физический адрес. . . . . . . . . : 4C-CC-6A-23-12-04
#    DHCP включен. . . . . . . . . . . : Да
#    Автонастройка включена. . . . . . : Да
# ...

# %% [markdown]
# ## Чтение и запись файлов

# %%
with open('heart.csv', 'r') as f:
    print(f.name, f.mode)
    #print(f.read())
    for index, line in enumerate(f.readlines()):
        if (index == 0 or index == 1):
            print(line)
# Out:
# heart.csv r
# age,sex,cp,trestbps,chol,fbs,restecg,thalach,exang,oldpeak,slope,ca,thal,target
#
# 63,1,3,145,233,1,0,150,0,2.3,0,0,1,1

# %%
with open('test.json', 'w') as f:
    f.write("{\"name\" : \"Test\"}")

# %%
with open('test.json', 'a+') as f:
    f.write("{\"name\" : \"Test\"}")

# %%
with open('test.json', 'r') as f:
    print(f.read())
# Out:
# {"name" : "Test"}{"name" : "Test"}

# %% [markdown]
# ## CSV files

# %%
import csv
with open('heart.csv', 'r') as f:
    csv_reader = csv.reader(f,delimiter=',')
    for index, line in enumerate(csv_reader):
        if index != 0:
            print(list(map(float,line)))
# Out:
# [63.0, 1.0, 3.0, 145.0, 233.0, 1.0, 0.0, 150.0, 0.0, 2.3, 0.0, 0.0, 1.0, 1.0]
# [37.0, 1.0, 2.0, 130.0, 250.0, 0.0, 1.0, 187.0, 0.0, 3.5, 0.0, 0.0, 2.0, 1.0]
# [41.0, 0.0, 1.0, 130.0, 204.0, 0.0, 0.0, 172.0, 0.0, 1.4, 2.0, 0.0, 2.0, 1.0]
# [56.0, 1.0, 1.0, 120.0, 236.0, 0.0, 1.0, 178.0, 0.0, 0.8, 2.0, 0.0, 2.0, 1.0]
# [57.0, 0.0, 0.0, 120.0, 354.0, 0.0, 1.0, 163.0, 1.0, 0.6, 2.0, 0.0, 2.0, 1.0]
# [57.0, 1.0, 0.0, 140.0, 192.0, 0.0, 1.0, 148.0, 0.0, 0.4, 1.0, 0.0, 1.0, 1.0]
# [56.0, 0.0, 1.0, 140.0, 294.0, 0.0, 0.0, 153.0, 0.0, 1.3, 1.0, 0.0, 2.0, 1.0]
# [44.0, 1.0, 1.0, 120.0, 263.0, 0.0, 1.0, 173.0, 0.0, 0.0, 2.0, 0.0, 3.0, 1.0]
# [52.0, 1.0, 2.0, 172.0, 199.0, 1.0, 1.0, 162.0, 0.0, 0.5, 2.0, 0.0, 3.0, 1.0]
# [57.0, 1.0, 2.0, 150.0, 168.0, 0.0, 1.0, 174.0, 0.0, 1.6, 2.0, 0.0, 2.0, 1.0]
# [54.0, 1.0, 0.0, 140.0, 239.0, 0.0, 1.0, 160.0, 0.0, 1.2, 2.0, 0.0, 2.0, 1.0]
# [48.0, 0.0, 2.0, 130.0, 275.0, 0.0, 1.0, 139.0, 0.0, 0.2, 2.0, 0.0, 2.0, 1.0]
# ...

# %%
with open('heart.csv', 'r') as f:
    csv_reader = csv.DictReader(f,delimiter=',')
    for line in csv_reader:
        print(line)
# Out:
# OrderedDict([('age', '63'), ('sex', '1'), ('cp', '3'), ('trestbps', '145'), ('chol', '233'), ('fbs', '1'), ('restecg', '0'), ('thalach', '150'), ('exang', '0'), ('oldpeak', '2.3'), ('slope', '0'), ('ca', '0'), ('thal', '1'), ('target', '1')])
# OrderedDict([('age', '37'), ('sex', '1'), ('cp', '2'), ('trestbps', '130'), ('chol', '250'), ('fbs', '0'), ('restecg', '1'), ('thalach', '187'), ('exang', '0'), ('oldpeak', '3.5'), ('slope', '0'), ('ca', '0'), ('thal', '2'), ('target', '1')])
# OrderedDict([('age', '41'), ('sex', '0'), ('cp', '1'), ('trestbps', '130'), ('chol', '204'), ('fbs', '0'), ('restecg', '0'), ('thalach', '172'), ('exang', '0'), ('oldpeak', '1.4'), ('slope', '2'), ('ca', '0'), ('thal', '2'), ('target', '1')])
# OrderedDict([('age', '56'), ('sex', '1'), ('cp', '1'), ('trestbps', '120'), ('chol', '236'), ('fbs', '0'), ('restecg', '1'), ('thalach', '178'), ('exang', '0'), ('oldpeak', '0.8'), ('slope', '2'), ('ca', '0'), ('thal', '2'), ('target', '1')])
# ...
